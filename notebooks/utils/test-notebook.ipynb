# %% [raw]
# root = 'blog'
# name = 'test-notebook'
# page = 1
# title = 'short title'
# subtitle = 'some more details, in title format'
# isPublished = false
# publishedOn = '2025-02-09T20:56:17.277Z'
# lastModifiedOn = '2025-02-09T20:56:17.277Z'

# %% [markdown]
# hello world

# %% [markdown]
# ![image.png](attachment:d692c614-622d-437c-a7b2-a748ec0694ec.png)
#
# ![image.png](attachment:21822bff-1cf4-4c46-ac76-8c4ad4b47419.png)
#
# ![image.png](attachment:204df0cc-587a-47d9-986a-64606bcb5ecf.png)

# %% [markdown]
# ## Excalidraw

# %% [raw]
# (() => {
#     return {
#         tool: 'excalidraw',
#         props: {
#             diagramUrl: '/assets/objects/utils/test.excalidraw',
#         }
#     }
# })()

# %% [markdown]
# ## DrawIO

# %% [raw]
# (() => {
#     return {
#         tool: 'drawio',
#         props: {
#             xmlUri: '/assets/objects/utils/test-diagram.drawio',
#             height: '600px'
#         }
#     }
# })()

# %%
import sys
for i in range(10):
    if i % 2 == 0:
        print('hello ', i)
    else:
        print('uh oho', i, file=sys.stderr)

hello
# Out:
# hello  0
# hello  2
# hello  4
# hello  6
# hello  8
# uh oho 1
# uh oho 3
# uh oho 5
# uh oho 7
# uh oho 9
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       5     else:
#       6         print('uh oho', i, file=sys.stderr)
# ----> 8 hello
#
# NameError: name 'hello' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Generate random data for a plot
x = np.linspace(0, 10, 100)
y = np.sin(x) + np.random.normal(scale=0.1, size=len(x))

plt.figure(figsize=(8, 5))
plt.plot(x, y, label="Noisy Sine Wave", color="blue", linewidth=2)
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("Sample Matplotlib Plot")
plt.legend()
plt.grid(True)
plt.show()

# Generate a sample DataFrame
data = {
    "A": np.random.randint(0, 100, 10),
    "B": np.random.rand(10),
    "C": np.random.choice(["Yes", "No"], 10),
}
df = pd.DataFrame(data)

# Display DataFrame
df
# Out:
#     A         B    C
# 0  90  0.114774  Yes
# 1  59  0.265851   No
# 2  91  0.004229  Yes
# 3  62  0.209416   No
# 4   6  0.880269   No
# 5  76  0.138058  Yes
# 6  82  0.184467   No
# 7  35  0.442307   No
# 8  75  0.551558  Yes
# 9  19  0.145065   No

# %% [markdown]
# ## Further Markdown-It testing
#
# ### Tabs
#
# ::: tabs#fruit
#
# @tab apple#apple
#
# Apple
#
# @tab banana#banana
#
# Banana
#
# :::
#
#
# ### Definition Lists
#
# First Term
# : This is the definition of the first term.
#
# Second Term
# : This is one definition of the second term.
# : This is another definition of the second term.
#
#
# ### Alert
#
# > [!warning]
# > This is warning text
# >
# > > [!warning]
# > > This is a nested warning
#
# - > [!warning]
#   > This is warning text
#
# ### Container
#
# ::: hint Here is a Hint
# :::
#
# ::: hint
#
# Here is a **hint** for you!
#
# - Hint 1
#   - Hint 1.1
#   - Hint 1.2
# - Hint 2
#
# :::
