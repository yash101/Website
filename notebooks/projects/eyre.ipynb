# %% [raw]
# root = 'projects'
# name = 'eyre'
# page = 1
# title = 'eyre'
# subtitle = "Delete supply chain risk"
# isPublished = true
#
# publishedOn = '2026-05-10T16:00:00.277Z'
# lastModifiedOn = '2026-05-10T16:00:00.277Z'
# authors = 'yash101'
#
# opengraph-image = '/objects/og-eyre-0.png'

# %% [markdown]
# Delete supply chain risk, choose Eyre!

# %% [markdown]
# Delete supply chain risk, choose Eyre!
